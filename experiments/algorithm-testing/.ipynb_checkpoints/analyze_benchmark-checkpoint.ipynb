# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("./2019-10-26-02/10x_max-1000ms_l-3.csv")
len(data)
# Out:
# 84

# %%
data
# Out:
#        algorithm  circuit name   number of actions   from waypoint  \
# 0   hybrid_astar         porto                  28               0
# 1   hybrid_astar         porto                  28               1
# 2   hybrid_astar         porto                  28               2
# 3   hybrid_astar         porto                  28               3
# 4   hybrid_astar         porto                  28               4
# ..           ...           ...                 ...             ...
# 79          sehs        zurich                  28               6
# 80          sehs        zurich                  28               7
# 81          sehs        zurich                  28               8
# 82          sehs        zurich                  28               9
# 83          sehs        zurich                  28              10
#
#      lookahead  finished within time limit  found solution   open nodes  \
# 0            3                         yes             yes       416149
# ...

# %%
combined_data = []

data.iloc[0]

# for i in range(0, int(len(data) / 7)):
#     if data.iloc[i]['found solution'] == 'no':
#         continue
    
#     total = 0
#     for j in range(i, 7):
#         total += data.iloc[j]['average computation time in ms']
#     combined_data.push({'sample': data.iloc[i], 'mean_computation_time': total / 7.0})

# combined_data
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/simon/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-8ffac692d596> in <module>()
#       5 for i in range(0, int(len(data) / 7)):
#       6     print(i)
# ...
