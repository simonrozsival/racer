# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-7e01270aa1c8> in <module>()
# ----> 1 import tensorflow as tf
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
max_rpm = 15350

input_files = ("telemetry-simulator.csv")
csvs = []
period = 5
for file in input_files:
    csv = pd.read_csv(file)
    csv["motor_rpm"] = np.convolve(csv["motor_rpm"], np.ones((period,)) / period, mode='same')
    csvs += [csv]
    
for csv in csvs:    
    plt.figure(figsize=(20, 10))
    plt.grid()
    #plt.plot(csv["throttle_input"], label="throttle")
    #plt.plot(csv["steering_angle_input"], label="steering angle")
    plt.plot(csv["motor_rpm"] / max_rpm, label="RPM")
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-83dacea15a45> in <module>()
#       5 period = 5
#       6 for file in input_files:
# ----> 7     csv = pd.read_csv(file)
#       8     csv["motor_rpm"] = np.convolve(csv["motor_rpm"], np.ones((period,)) / period, mode='same')
#       9     csvs += [csv]
#
# NameError: name 'pd' is not defined

# %%
# I want the intput to be in the form of:
# (current RPM, throttle input, steering input, RPM change rate)

import numpy as np

data = np.array(np.zeros(4))

for csv in csvs:
    previous_rpm = 0
    for index, row in csv.iterrows():
        next_rpm = row["motor_rpm"] / max_rpm       
        previous_rpm = next_rpm
        
        record = [previous_rpm, row["throttle_input"], row["steering_angle_input"], next_rpm]
        
        data = np.vstack((data, record))

plt.figure(figsize=(20, 10))
plt.grid()
plt.plot(data[:, 0], label="current rpm")
plt.plot(data[:, 1], label="throttle")
plt.plot(data[:, 2], label="steering angle")
plt.legend()
plt.show()

# %%
#np.random.shuffle(data)

training_portion = 0.8
split_point = int(len(data)*training_portion)
train = data[:split_point,:]
test = data[split_point:,:]

x_test = test[:, :-1]
y_test = test[:, -1]

x_train = train[:, :-1]
y_train = train[:, -1]

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(len(x_test[0]), activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(5, activation='relu'),
  tf.keras.layers.Dense(2, activation='relu'),
  tf.keras.layers.Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),
              loss='mean_squared_error',
              metrics=['mean_absolute_error', 'mean_squared_error'])

model.fit(x_train, y_train, epochs=50, use_multiprocessing=True)

model.evaluate(x_test, y_test)
# Out:
# Train on 11787 samples
# Epoch 1/50
# 11787/11787 [==============================] - 2s 164us/sample - loss: 0.0623 - mean_absolute_error: 0.1829 - mean_squared_error: 0.0623
# Epoch 2/50
# 11787/11787 [==============================] - 1s 72us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 3/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0454 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0454
# Epoch 4/50
# 11787/11787 [==============================] - 1s 67us/sample - loss: 0.0453 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0453
# Epoch 5/50
# 11787/11787 [==============================] - 1s 64us/sample - loss: 0.0454 - mean_absolute_error: 0.1676 - mean_squared_error: 0.0454
# Epoch 6/50
# 11787/11787 [==============================] - 1s 58us/sample - loss: 0.0453 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0453
# Epoch 7/50
# 11787/11787 [==============================] - 1s 56us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 8/50
# 11787/11787 [==============================] - 1s 53us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 9/50
# 11787/11787 [==============================] - 1s 53us/sample - loss: 0.0454 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0454
# Epoch 10/50
# 11787/11787 [==============================] - 1s 59us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 11/50
# 11787/11787 [==============================] - 1s 56us/sample - loss: 0.0453 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0453
# Epoch 12/50
# 11787/11787 [==============================] - 1s 53us/sample - loss: 0.0453 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0453
# Epoch 13/50
# 11787/11787 [==============================] - 1s 58us/sample - loss: 0.0453 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0453
# Epoch 14/50
# 11787/11787 [==============================] - 1s 59us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 15/50
# 11787/11787 [==============================] - 1s 58us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 16/50
# 11787/11787 [==============================] - 1s 57us/sample - loss: 0.0453 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0453
# Epoch 17/50
# 11787/11787 [==============================] - 1s 55us/sample - loss: 0.0453 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0453
# Epoch 18/50
# 11787/11787 [==============================] - 1s 61us/sample - loss: 0.0453 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0453
# Epoch 19/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0453 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0453
# Epoch 20/50
# 11787/11787 [==============================] - 1s 57us/sample - loss: 0.0453 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0453
# Epoch 21/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 22/50
# 11787/11787 [==============================] - 1s 70us/sample - loss: 0.0453 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0453
# Epoch 23/50
# 11787/11787 [==============================] - 1s 66us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 24/50
# 11787/11787 [==============================] - 1s 58us/sample - loss: 0.0453 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0453
# Epoch 25/50
# 11787/11787 [==============================] - 1s 73us/sample - loss: 0.0453 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0453
# Epoch 26/50
# 11787/11787 [==============================] - 1s 100us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 27/50
# 11787/11787 [==============================] - 1s 77us/sample - loss: 0.0453 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0453
# Epoch 28/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0454 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0454
# Epoch 29/50
# 11787/11787 [==============================] - 1s 55us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 30/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0453 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0453
# Epoch 31/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 32/50
# 11787/11787 [==============================] - 1s 56us/sample - loss: 0.0453 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0453
# Epoch 33/50
# 11787/11787 [==============================] - 1s 63us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 34/50
# 11787/11787 [==============================] - 1s 55us/sample - loss: 0.0453 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0453
# Epoch 35/50
# 11787/11787 [==============================] - 1s 53us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 36/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 37/50
# 11787/11787 [==============================] - 1s 53us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 38/50
# 11787/11787 [==============================] - 1s 52us/sample - loss: 0.0453 - mean_absolute_error: 0.1675 - mean_squared_error: 0.0453
# Epoch 39/50
# 11787/11787 [==============================] - 1s 52us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 40/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0453 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0453
# Epoch 41/50
# 11787/11787 [==============================] - 1s 56us/sample - loss: 0.0453 - mean_absolute_error: 0.1676 - mean_squared_error: 0.0453
# Epoch 42/50
# 11787/11787 [==============================] - 1s 64us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 43/50
# 11787/11787 [==============================] - 1s 77us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 44/50
# 11787/11787 [==============================] - 1s 61us/sample - loss: 0.0453 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0453
# Epoch 45/50
# 11787/11787 [==============================] - 1s 54us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 46/50
# 11787/11787 [==============================] - 1s 71us/sample - loss: 0.0453 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0453
# Epoch 47/50
# 11787/11787 [==============================] - 1s 71us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 48/50
# 11787/11787 [==============================] - 1s 68us/sample - loss: 0.0454 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0454
# Epoch 49/50
# 11787/11787 [==============================] - 1s 71us/sample - loss: 0.0453 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0453
# Epoch 50/50
# 11787/11787 [==============================] - 1s 53us/sample - loss: 0.0454 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0454
# 2947/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.03441112716825651, 0.13140559, 0.034411125]

# %%
predicted_rpm = []
rpm = 0
for row in data[:500]:
    rpm = float(model.predict([(rpm, row[1], row[2])])[0][0])
    predicted_rpm += [rpm]

# %%
plt.figure(figsize=(20, 10))
plt.grid()
plt.plot(data[:len(predicted_rpm), 1], label="throttle")
#plt.plot(data[:1000, 1], label="steering angle")
#plt.plot(data[:,-1], 'b', label="measured RPM")
plt.plot(predicted_rpm, 'r', label="predicted RPM")
plt.legend()
lt.show()

# %%
import neat
import random

def predict(net, offset, n):
    rpm = data[offset, 0]
    for row in data[offset:(offset + n)]:
        rpm = net.activate((rpm, row[1], row[2]))[0]
        yield rpm

def activate_for(net, offset, n):
    for row in data[offset:(offset + n)]:
        yield net.activate((row[0], row[1], row[2]))[0]
        
def calculate_error(net, offset, n):
    error_sq = 0
    prediction = activate_for(net, offset, n)
    ref = data[offset:(offset + n), 3]
    for (rpm, target_rpm) in zip(prediction, ref):
        error_sq += (rpm - target_rpm) ** 2
        
    return error_sq

def eval_genomes(genomes, config):
    n = 10
    k = 20
    for genome_id, genome in genomes:
        genome.fitness = 0
            
    for i in range(k):
        offset = random.randint(0, len(data) - n)
        for genome_id, genome in genomes:
            net = neat.nn.FeedForwardNetwork.create(genome, config)
            err = calculate_error(net, offset, n)
            genome.fitness -= err

config_file = "./evolution-config.ini"
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

# Create the population, which is the top-level object for a NEAT run.
p = neat.Population(config)

# Add a stdout reporter to show progress in the terminal.
p.add_reporter(neat.StdOutReporter(True))
stats = neat.StatisticsReporter()
p.add_reporter(stats)
p.add_reporter(neat.Checkpointer(5))

# Run for up to N generations.
N = 200
evaluator = neat.parallel.ParallelEvaluator(8, eval_genomes)
winner = p.run(eval_genomes, N)

# Display the winning genome.
print('\nBest genome:\n{!s}'.format(winner))

# Show output of the most fit genome against training data.
print('\nOutput:')
winner_net = neat.nn.FeedForwardNetwork.create(winner, config)

# visualize.draw_net(config, winner, True, node_names=node_names)
# visualize.plot_stats(stats, ylog=False, view=True)
# visualize.plot_species(stats, view=True)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -66.56404 stdev: 59.29149
# Best fitness: -2.08618 - size: (6, 20) - species 1 - id 638
# Average adjusted fitness: 0.553
# Mean genetic distance 1.155, standard deviation 0.194
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0  1000    -66.6    0.553     0
# Total extinctions: 0
# Generation time: 13.353 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -42.03656 stdev: 29.03690
# Best fitness: -3.32567 - size: (6, 19) - species 1 - id 1657
# Average adjusted fitness: 0.627
# Mean genetic distance 1.242, standard deviation 0.207
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1  1000    -42.0    0.627     0
# Total extinctions: 0
# Generation time: 9.824 sec (11.589 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -45.66958 stdev: 24.80341
# Best fitness: -2.95608 - size: (6, 19) - species 1 - id 1657
# Average adjusted fitness: 0.596
# Mean genetic distance 1.350, standard deviation 0.234
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2  1000    -45.7    0.596     1
# Total extinctions: 0
# Generation time: 13.075 sec (12.084 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -44.68623 stdev: 44.45849
# Best fitness: -2.64693 - size: (4, 12) - species 1 - id 3388
# Average adjusted fitness: 0.670
# Mean genetic distance 1.530, standard deviation 0.253
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3  1000    -44.7    0.670     2
# Total extinctions: 0
# Generation time: 10.698 sec (11.738 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -41.91533 stdev: 30.28531
# Best fitness: -2.88259 - size: (4, 12) - species 1 - id 3388
# Average adjusted fitness: 0.614
# Mean genetic distance 1.669, standard deviation 0.267
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4  1000    -41.9    0.614     0
# Total extinctions: 0
# Generation time: 9.269 sec (11.244 average)
# Saving checkpoint to neat-checkpoint-4
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -40.12893 stdev: 41.26144
# Best fitness: -1.54149 - size: (5, 12) - species 1 - id 5115
# Average adjusted fitness: 0.691
# Mean genetic distance 1.734, standard deviation 0.238
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5  1000    -40.1    0.691     0
# Total extinctions: 0
# Generation time: 7.614 sec (10.639 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -41.13495 stdev: 21.68592
# Best fitness: -1.11322 - size: (6, 18) - species 1 - id 6036
# Average adjusted fitness: 0.580
# Mean genetic distance 1.865, standard deviation 0.285
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6  1000    -41.1    0.580     1
# Total extinctions: 0
# Generation time: 7.839 sec (10.239 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -39.35029 stdev: 37.87198
# Best fitness: -0.56961 - size: (5, 10) - species 1 - id 7400
# Average adjusted fitness: 0.670
# Mean genetic distance 1.981, standard deviation 0.271
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7  1000    -39.4    0.670     0
# Total extinctions: 0
# Generation time: 7.140 sec (9.852 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -34.21551 stdev: 31.41094
# Best fitness: -0.19902 - size: (5, 12) - species 1 - id 8863
# Average adjusted fitness: 0.708
# Mean genetic distance 1.950, standard deviation 0.248
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8  1000    -34.2    0.708     0
# Total extinctions: 0
# Generation time: 8.402 sec (9.690 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -33.89689 stdev: 32.46213
# Best fitness: -0.17333 - size: (5, 13) - species 1 - id 8223
# Average adjusted fitness: 0.695
# Mean genetic distance 1.957, standard deviation 0.249
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9  1000    -33.9    0.695     0
# Total extinctions: 0
# Generation time: 6.950 sec (9.416 average)
# Saving checkpoint to neat-checkpoint-9
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -29.01442 stdev: 32.70021
# Best fitness: -0.31441 - size: (5, 12) - species 1 - id 8863
# Average adjusted fitness: 0.759
# Mean genetic distance 1.881, standard deviation 0.258
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10  1000    -29.0    0.759     0
# Total extinctions: 0
# Generation time: 5.167 sec (8.598 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -26.53857 stdev: 25.67362
# Best fitness: -0.21448 - size: (5, 12) - species 1 - id 8863
# Average adjusted fitness: 0.746
# Mean genetic distance 1.878, standard deviation 0.242
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11  1000    -26.5    0.746     0
# Total extinctions: 0
# Generation time: 5.027 sec (8.118 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -25.18189 stdev: 35.34262
# Best fitness: -0.25362 - size: (5, 7) - species 1 - id 12266
# Average adjusted fitness: 0.814
# Mean genetic distance 1.961, standard deviation 0.248
# Population of 1000 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12  1000    -25.2    0.814     0
# Total extinctions: 0
# Generation time: 5.364 sec (7.347 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -24.49733 stdev: 26.45919
# Best fitness: -0.23268 - size: (6, 8) - species 1 - id 13057
# Average adjusted fitness: 0.774
# Mean genetic distance 2.136, standard deviation 0.392
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   646    -24.5    0.774     0
#      2    0   354       --       --     0
# Total extinctions: 0
# Generation time: 3.640 sec (6.641 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -26.13293 stdev: 30.29243
# Best fitness: -0.27582 - size: (5, 5) - species 1 - id 14898
# Average adjusted fitness: 0.777
# Mean genetic distance 2.208, standard deviation 0.400
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   462    -26.3    0.775     1
#      2    1   538    -25.9    0.779     0
# Total extinctions: 0
# Generation time: 3.342 sec (6.049 average)
# Saving checkpoint to neat-checkpoint-14
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -24.12051 stdev: 31.50415
# Best fitness: -0.11331 - size: (4, 6) - species 1 - id 14290
# Average adjusted fitness: 0.791
# Mean genetic distance 2.115, standard deviation 0.388
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   236    -26.5    0.772     2
#      2    2   764    -22.1    0.810     0
# Total extinctions: 0
# Generation time: 5.329 sec (5.820 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -25.07111 stdev: 27.19570
# Best fitness: -0.19276 - size: (4, 3) - species 2 - id 16101
# Average adjusted fitness: 0.759
# Mean genetic distance 2.114, standard deviation 0.380
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   660    -27.5    0.745     3
#      2    3   340    -24.3    0.774     1
# Total extinctions: 0
# Generation time: 3.718 sec (5.408 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -27.27681 stdev: 25.02747
# Best fitness: -0.22277 - size: (8, 11) - species 1 - id 17933
# Average adjusted fitness: 0.725
# Mean genetic distance 2.241, standard deviation 0.386
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   392    -28.0    0.714     4
#      2    4   495    -25.8    0.737     2
#      3    0   113       --       --     0
# Total extinctions: 0
# Generation time: 3.937 sec (5.088 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -25.27458 stdev: 27.43755
# Best fitness: -0.28937 - size: (4, 6) - species 1 - id 14290
# Average adjusted fitness: 0.771
# Mean genetic distance 2.243, standard deviation 0.372
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   470    -25.9    0.767     5
#      2    5   250    -24.7    0.778     3
#      3    1   280    -25.8    0.768     0
# Total extinctions: 0
# Generation time: 3.786 sec (4.626 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -23.20976 stdev: 26.77604
# Best fitness: -0.23202 - size: (3, 4) - species 3 - id 19871
# Average adjusted fitness: 0.800
# Mean genetic distance 2.246, standard deviation 0.340
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   435    -22.3    0.809     0
#      2    6   282    -23.9    0.796     4
#      3    2   269    -24.1    0.794     0
#      4    0    14       --       --     0
# Total extinctions: 0
# Generation time: 3.475 sec (4.279 average)
# Saving checkpoint to neat-checkpoint-19
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -22.78819 stdev: 26.08555
# Best fitness: -0.28628 - size: (4, 5) - species 2 - id 20432
# Average adjusted fitness: 0.797
# Mean genetic distance 2.269, standard deviation 0.369
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20   246    -25.0    0.784     1
#      2    7   351    -20.1    0.827     0
#      3    3    62    -21.7    0.813     0
#      4    1   341    -27.1    0.766     0
# Total extinctions: 0
# Generation time: 3.555 sec (4.117 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -23.10334 stdev: 35.34502
# Best fitness: -0.22671 - size: (6, 7) - species 4 - id 21782
# Average adjusted fitness: 0.839
# Mean genetic distance 2.215, standard deviation 0.345
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21   260    -24.9    0.814     2
#      2    8   153    -25.4    0.810     1
#      3    4   148    -15.5    0.885     0
#      4    2   439    -20.8    0.845     0
# Total extinctions: 0
# Generation time: 3.261 sec (3.941 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -25.76068 stdev: 26.85490
# Best fitness: -0.28820 - size: (4, 5) - species 4 - id 22757
# Average adjusted fitness: 0.765
# Mean genetic distance 2.241, standard deviation 0.339
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22   169    -25.0    0.771     3
#      2    9   146    -29.4    0.730     2
#      3    5   285    -21.9    0.800     1
#      4    3   400    -26.2    0.759     1
# Total extinctions: 0
# Generation time: 3.382 sec (3.743 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -23.50251 stdev: 33.72349
# Best fitness: -0.18260 - size: (6, 7) - species 3 - id 22050
# Average adjusted fitness: 0.809
# Mean genetic distance 2.184, standard deviation 0.353
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    60    -18.7    0.850     0
#      2   10    83    -29.5    0.762     3
#      3    6   615    -22.0    0.823     2
#      4    4   242    -24.4    0.803     2
# Total extinctions: 0
# Generation time: 4.020 sec (3.781 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -18.89429 stdev: 33.67278
# Best fitness: -0.09666 - size: (6, 5) - species 3 - id 24096
# Average adjusted fitness: 0.864
# Mean genetic distance 2.155, standard deviation 0.337
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24   112    -17.5    0.878     0
#      2   11   204    -22.5    0.843     4
#      3    7   385    -18.2    0.873     3
#      4    5   299    -19.7    0.863     0
# Total extinctions: 0
# Generation time: 2.845 sec (3.731 average)
# Saving checkpoint to neat-checkpoint-24
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -23.11071 stdev: 27.80127
# Best fitness: -0.19492 - size: (6, 10) - species 2 - id 25024
# Average adjusted fitness: 0.791
# Mean genetic distance 2.186, standard deviation 0.323
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25   223    -23.9    0.785     1
#      2   12   299    -21.9    0.802     5
#      3    8   215    -22.9    0.793     4
#      4    6   263    -23.9    0.785     1
# Total extinctions: 0
# Generation time: 2.848 sec (3.483 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -24.88063 stdev: 26.84615
# Best fitness: -0.07946 - size: (5, 3) - species 4 - id 24969
# Average adjusted fitness: 0.760
# Mean genetic distance 2.152, standard deviation 0.340
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26   162    -28.8    0.722     2
#      2   13    35    -23.4    0.773     6
#      3    9   277    -19.3    0.813     5
#      4    7   526    -27.8    0.731     2
# Total extinctions: 0
# Generation time: 3.214 sec (3.432 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -22.14814 stdev: 30.59396
# Best fitness: -0.37688 - size: (6, 11) - species 4 - id 25603
# Average adjusted fitness: 0.834
# Mean genetic distance 2.137, standard deviation 0.375
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27   120    -21.7    0.835     3
#      2   14    30    -22.0    0.833     7
#      3   10   654    -20.7    0.843     6
#      4    8   196    -23.1    0.825     3
# Total extinctions: 0
# Generation time: 2.509 sec (3.290 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -24.95280 stdev: 26.24848
# Best fitness: -0.33630 - size: (9, 7) - species 3 - id 28544
# Average adjusted fitness: 0.779
# Mean genetic distance 2.156, standard deviation 0.369
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28   274    -28.0    0.739     4
#      2   15    70    -18.5    0.829     0
#      3   11   411    -25.0    0.768     7
#      4    9   244    -23.9    0.778     4
#      5    0     1       --       --     0
# Total extinctions: 0
# Generation time: 3.018 sec (3.213 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -23.98747 stdev: 28.50116
# Best fitness: -0.19987 - size: (4, 4) - species 2 - id 27287
# Average adjusted fitness: 0.822
# Mean genetic distance 2.205, standard deviation 0.388
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    85    -24.9    0.777     5
#      2   16    30    -19.6    0.825     1
#      3   12   160    -23.8    0.787     8
#      4   10   720    -24.6    0.780     5
#      5    1     5     -6.7    0.941     0
# Total extinctions: 0
# Generation time: 2.969 sec (3.162 average)
# Saving checkpoint to neat-checkpoint-29
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -24.00718 stdev: 26.10008
# Best fitness: -0.17023 - size: (6, 3) - species 4 - id 29392
# Average adjusted fitness: 0.758
# Mean genetic distance 2.204, standard deviation 0.401
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30   196    -28.9    0.734     6
#      2   17    89    -37.8    0.652     2
#      3   13   116    -22.6    0.793     9
#      4   11   591    -23.2    0.787     6
#      5    2     8    -19.3    0.823     1
# Total extinctions: 0
# Generation time: 2.961 sec (3.103 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -25.17917 stdev: 28.14287
# Best fitness: -0.07275 - size: (6, 3) - species 4 - id 29392
# Average adjusted fitness: 0.748
# Mean genetic distance 2.204, standard deviation 0.389
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    44    -22.7    0.782     7
#      2   18    54    -24.9    0.761     3
#      3   14    71    -29.4    0.717    10
#      4   12   821    -25.2    0.758     7
#      5    3    10    -29.0    0.721     2
# Total extinctions: 0
# Generation time: 2.567 sec (3.033 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -24.26339 stdev: 23.59251
# Best fitness: -0.09619 - size: (6, 3) - species 4 - id 29392
# Average adjusted fitness: 0.760
# Mean genetic distance 2.183, standard deviation 0.430
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    39    -24.5    0.736     8
#      2   19   248    -19.8    0.787     4
#      3   15   196    -24.5    0.736    11
#      4   13   505    -24.6    0.735     8
#      5    4    12    -18.1    0.806     3
# Total extinctions: 0
# Generation time: 3.156 sec (3.011 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -25.49007 stdev: 26.27788
# Best fitness: -0.23660 - size: (6, 3) - species 4 - id 29392
# Average adjusted fitness: 0.756
# Mean genetic distance 2.079, standard deviation 0.444
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    70    -25.6    0.755     9
#      2   20   273    -28.5    0.726     5
#      3   16   371    -26.0    0.751    12
#      4   14   273    -23.9    0.771     9
#      5    5    13    -23.4    0.775     4
# Total extinctions: 0
# Generation time: 3.244 sec (2.933 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -26.01987 stdev: 27.40681
# Best fitness: -0.13215 - size: (10, 10) - species 3 - id 34104
# Average adjusted fitness: 0.753
# Mean genetic distance 2.072, standard deviation 0.419
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34   117    -26.4    0.745    10
#      2   21   255    -25.4    0.755     6
#      3   17   431    -25.8    0.751    13
#      4   15   182    -27.0    0.739    10
#      5    6    15    -23.6    0.772     5
# Total extinctions: 0
# Generation time: 3.422 sec (2.991 average)
# Saving checkpoint to neat-checkpoint-34
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -23.36257 stdev: 27.28855
# Best fitness: -0.21764 - size: (6, 3) - species 3 - id 33195
# Average adjusted fitness: 0.780
# Mean genetic distance 2.050, standard deviation 0.369
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35   136    -24.2    0.787    11
#      2   22   258    -22.0    0.807     7
#      3   18    68    -24.2    0.787    14
#      4   16   520    -22.1    0.805    11
#      5    7    18    -32.4    0.714     6
# Total extinctions: 0
# Generation time: 4.002 sec (3.106 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -25.71518 stdev: 23.59399
# Best fitness: -0.16814 - size: (6, 3) - species 1 - id 33195
# Average adjusted fitness: 0.698
# Mean genetic distance 2.163, standard deviation 0.414
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    83    -28.8    0.689    12
#      2   23   142    -24.5    0.735     8
#      3   19   103    -24.9    0.731    15
#      4   17   653    -25.2    0.727    12
#      5    8    19    -35.9    0.611     7
# Total extinctions: 0
# Generation time: 3.202 sec (3.105 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -26.02109 stdev: 25.62765
# Best fitness: -0.07304 - size: (6, 3) - species 4 - id 33195
# Average adjusted fitness: 0.720
# Mean genetic distance 2.175, standard deviation 0.398
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37   120    -26.7    0.723    13
#      2   24    51    -22.4    0.768     9
#      3   20   460    -27.8    0.711    16
#      4   18   345    -26.3    0.727    13
#      5    9    24    -31.7    0.671     8
# Total extinctions: 0
# Generation time: 3.159 sec (3.170 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -24.90545 stdev: 32.87158
# Best fitness: -0.30265 - size: (9, 9) - species 4 - id 38382
# Average adjusted fitness: 0.796
# Mean genetic distance 2.112, standard deviation 0.376
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    85    -23.5    0.817    14
#      2   25     9    -25.0    0.806    10
#      3   21   412    -23.2    0.820    17
#      4   19   466    -27.2    0.788    14
#      5   10    28    -32.0    0.750     9
# Total extinctions: 0
# Generation time: 2.813 sec (3.150 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -23.25409 stdev: 36.54619
# Best fitness: -0.22160 - size: (9, 9) - species 4 - id 38382
# Average adjusted fitness: 0.821
# Mean genetic distance 2.107, standard deviation 0.376
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    45    -17.2    0.874     0
#      2   26   387    -23.2    0.829    11
#      3   22   337    -17.5    0.871    18
#      4   20   209    -28.8    0.787    15
#      5   11    22    -34.5    0.744    10
# Total extinctions: 0
# Generation time: 3.335 sec (3.186 average)
# Saving checkpoint to neat-checkpoint-39
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -25.75738 stdev: 24.66207
# Best fitness: -0.19159 - size: (4, 3) - species 3 - id 39325
# Average adjusted fitness: 0.727
# Mean genetic distance 2.124, standard deviation 0.338
# Population of 1000 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    55    -22.5    0.768     1
#      2   27   459    -26.1    0.732    12
#      3   23   158    -25.7    0.735    19
#      4   21   303    -25.1    0.741    16
#      5   12    25    -33.3    0.657    11
# Total extinctions: 0
# Generation time: 3.015 sec (3.192 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -24.15142 stdev: 32.03538
# Best fitness: -0.28791 - size: (11, 9) - species 1 - id 41167
#
# Species 3 with 158 members is stagnated: removing it
# Average adjusted fitness: 0.782
# Mean genetic distance 2.159, standard deviation 0.307
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41   105    -25.4    0.799     2
#      2   28   471    -26.1    0.793    13
#      4   22   393    -21.3    0.832    17
#      5   13    31    -37.5    0.703    12
# Total extinctions: 0
# Generation time: 3.093 sec (3.244 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -24.97037 stdev: 26.44534
# Best fitness: -0.13204 - size: (6, 3) - species 4 - id 42557
# Average adjusted fitness: 0.735
# Mean genetic distance 2.177, standard deviation 0.304
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42   112    -22.6    0.781     3
#      2   29    71    -24.3    0.765    14
#      4   23   795    -25.4    0.755    18
#      5   14    22    -37.3    0.639    13
# Total extinctions: 0
# Generation time: 3.767 sec (3.305 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -22.82737 stdev: 29.61665
# Best fitness: -0.13771 - size: (6, 3) - species 4 - id 42557
# Average adjusted fitness: 0.789
# Mean genetic distance 2.212, standard deviation 0.322
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43   238    -25.8    0.777     4
#      2   30    87    -19.6    0.832    15
#      4   24   654    -22.5    0.806    19
#      5   15    21    -30.1    0.740    14
# Total extinctions: 0
# Generation time: 3.742 sec (3.355 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -24.24336 stdev: 31.81594
# Best fitness: -0.28573 - size: (8, 4) - species 1 - id 44442
#
# Species 4 with 654 members is stagnated: removing it
# Average adjusted fitness: 0.794
# Mean genetic distance 2.185, standard deviation 0.472
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44   119    -22.2    0.825     5
#      2   31   832    -17.8    0.860     0
#      5   16    49    -38.0    0.698    15
# Total extinctions: 0
# Generation time: 3.419 sec (3.355 average)
# Saving checkpoint to neat-checkpoint-44
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -22.41214 stdev: 29.84634
# Best fitness: -0.22565 - size: (8, 4) - species 2 - id 44442
# Average adjusted fitness: 0.806
# Mean genetic distance 2.102, standard deviation 0.486
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45   121    -20.1    0.838     6
#      2   32   838    -22.3    0.819     1
#      5   17    41    -29.6    0.760    16
# Total extinctions: 0
# Generation time: 2.942 sec (3.249 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -25.78575 stdev: 23.12367
# Best fitness: -0.13750 - size: (8, 5) - species 2 - id 46029
# Average adjusted fitness: 0.706
# Mean genetic distance 2.103, standard deviation 0.465
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46   197    -27.5    0.709     7
#      2   33   774    -25.3    0.732     2
#      5   18    29    -30.3    0.679    17
# Total extinctions: 0
# Generation time: 3.577 sec (3.286 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -22.45197 stdev: 32.84145
# Best fitness: -0.30003 - size: (8, 4) - species 2 - id 44442
# Average adjusted fitness: 0.823
# Mean genetic distance 2.148, standard deviation 0.480
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47   130    -20.9    0.842     8
#      2   34   842    -22.7    0.829     3
#      5   19    28    -27.0    0.796    18
# Total extinctions: 0
# Generation time: 3.091 sec (3.279 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: -20.80013 stdev: 27.58749
# Best fitness: -0.19405 - size: (10, 5) - species 2 - id 47793
# Average adjusted fitness: 0.845
# Mean genetic distance 2.335, standard deviation 0.490
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48   378    -21.2    0.826     9
#      2   35   542    -20.9    0.828     4
#      5   20    40    -14.5    0.881    19
#      6    0    40       --       --     0
# Total extinctions: 0
# Generation time: 3.088 sec (3.307 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -20.12352 stdev: 33.80441
# Best fitness: -0.21640 - size: (10, 6) - species 2 - id 48973
#
# Species 5 with 40 members is stagnated: removing it
# Average adjusted fitness: 0.840
# Mean genetic distance 2.269, standard deviation 0.432
# Population of 1001 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49   486    -19.6    0.858    10
#      2   36   366    -19.7    0.858     5
#      6    1   149    -27.1    0.803     0
# Total extinctions: 0
# Generation time: 3.012 sec (3.275 average)
# Saving checkpoint to neat-checkpoint-49
#
#  ****** Running generation 50 ******
#
# Population's average fitness: -24.51446 stdev: 26.07746
# Best fitness: -0.23102 - size: (5, 4) - species 1 - id 50652
# Average adjusted fitness: 0.769
# Mean genetic distance 2.164, standard deviation 0.330
# Population of 1001 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50   498    -23.5    0.781    11
#      2   37   337    -25.4    0.764     6
#      6    2   166    -25.6    0.762     0
# Total extinctions: 0
# Generation time: 3.059 sec (3.279 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: -22.57408 stdev: 27.45884
# Best fitness: -0.27455 - size: (5, 4) - species 1 - id 50930
# Average adjusted fitness: 0.804
# Mean genetic distance 2.217, standard deviation 0.338
# Population of 1001 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51   197    -24.3    0.790    12
#      2   38    51    -19.0    0.836     7
#      6    3   753    -24.7    0.786     0
# Total extinctions: 0
# Generation time: 3.397 sec (3.309 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: -25.11554 stdev: 22.15182
# Best fitness: -0.16482 - size: (6, 5) - species 6 - id 51255
# Average adjusted fitness: 0.719
# Mean genetic distance 2.255, standard deviation 0.332
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52   440    -24.6    0.720    13
#      2   39   443    -24.3    0.724     8
#      6    4   117    -25.3    0.712     1
# Total extinctions: 0
# Generation time: 3.025 sec (3.235 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: -22.18387 stdev: 27.00873
# Best fitness: -0.10227 - size: (5, 5) - species 2 - id 53129
# Average adjusted fitness: 0.806
# Mean genetic distance 2.345, standard deviation 0.309
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53   336    -24.6    0.781    14
#      2   40   334    -20.3    0.819     9
#      6    5   330    -20.5    0.817     0
# Total extinctions: 0
# Generation time: 3.237 sec (3.185 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: -23.73070 stdev: 25.77632
# Best fitness: -0.18846 - size: (8, 4) - species 1 - id 52852
# Average adjusted fitness: 0.778
# Mean genetic distance 2.373, standard deviation 0.310
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54   434    -21.1    0.803    15
#      2   41   289    -25.3    0.763    10
#      6    6   277    -24.9    0.767     1
# Total extinctions: 0
# Generation time: 3.645 sec (3.207 average)
# Saving checkpoint to neat-checkpoint-54
#
#  ****** Running generation 55 ******
#
# Population's average fitness: -23.14782 stdev: 33.76950
# Best fitness: -0.30449 - size: (9, 8) - species 1 - id 54660
# Average adjusted fitness: 0.826
# Mean genetic distance 2.287, standard deviation 0.310
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55   301    -21.9    0.837    16
#      2   42   335    -28.4    0.788    11
#      6    7   364    -19.7    0.854     0
# Total extinctions: 0
# Generation time: 3.146 sec (3.228 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: -25.94244 stdev: 22.38000
# Best fitness: -0.05280 - size: (8, 8) - species 2 - id 55765
# Average adjusted fitness: 0.682
# Mean genetic distance 2.227, standard deviation 0.305
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56   320    -26.2    0.679    17
#      2   43   405    -27.0    0.669    12
#      6    8   275    -24.8    0.696     1
# Total extinctions: 0
# Generation time: 3.398 sec (3.210 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: -21.10037 stdev: 32.31124
# Best fitness: -0.22869 - size: (8, 9) - species 2 - id 56700
# Average adjusted fitness: 0.837
# Mean genetic distance 2.283, standard deviation 0.325
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57   360    -20.8    0.841    18
#      2   44    77    -20.0    0.847    13
#      6    9   563    -23.0    0.824     2
# Total extinctions: 0
# Generation time: 3.250 sec (3.226 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: -24.95785 stdev: 30.13824
# Best fitness: -0.34381 - size: (8, 9) - species 6 - id 56700
# Average adjusted fitness: 0.778
# Mean genetic distance 2.339, standard deviation 0.334
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58   465    -26.4    0.781    19
#      2   45    48    -30.5    0.746    14
#      6   10   487    -23.3    0.807     3
# Total extinctions: 0
# Generation time: 2.768 sec (3.194 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: -22.18444 stdev: 31.17019
# Best fitness: -0.26532 - size: (8, 9) - species 1 - id 56700
#
# Species 1 with 465 members is stagnated: removing it
# Average adjusted fitness: 0.812
# Mean genetic distance 2.294, standard deviation 0.334
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   46    60    -26.2    0.798    15
#      6   11   818    -22.6    0.826     4
#      7    0   122       --       --     0
# Total extinctions: 0
# Generation time: 3.058 sec (3.198 average)
# Saving checkpoint to neat-checkpoint-59
#
#  ****** Running generation 60 ******
#
# Population's average fitness: -22.41134 stdev: 31.98943
# Best fitness: -0.23970 - size: (10, 7) - species 6 - id 59278
# Average adjusted fitness: 0.778
# Mean genetic distance 2.304, standard deviation 0.307
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   47   410    -41.4    0.683    16
#      6   12   139    -20.6    0.843     5
#      7    1   451    -25.3    0.807     0
# Total extinctions: 0
# Generation time: 5.057 sec (3.398 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: -23.30770 stdev: 30.10751
# Best fitness: -0.11776 - size: (10, 9) - species 2 - id 59915
# Average adjusted fitness: 0.810
# Mean genetic distance 2.405, standard deviation 0.306
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   48   137    -24.5    0.782    17
#      6   13   266    -14.6    0.871     0
#      7    2   597    -24.9    0.778     0
# Total extinctions: 0
# Generation time: 3.341 sec (3.392 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: -23.76527 stdev: 25.63248
# Best fitness: -0.24400 - size: (10, 9) - species 6 - id 59915
# Average adjusted fitness: 0.783
# Mean genetic distance 2.500, standard deviation 0.309
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   49    59    -24.8    0.775    18
#      6   14   481    -23.0    0.792     1
#      7    3   460    -23.9    0.784     0
# Total extinctions: 0
# Generation time: 3.145 sec (3.404 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: -22.21604 stdev: 34.91608
# Best fitness: -0.43035 - size: (10, 14) - species 7 - id 63004
# Average adjusted fitness: 0.841
# Mean genetic distance 2.412, standard deviation 0.325
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   50    61    -25.6    0.825    19
#      6   15   498    -22.1    0.849     2
#      7    4   441    -21.9    0.850     0
# Total extinctions: 0
# Generation time: 3.295 sec (3.410 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: -22.48407 stdev: 29.31069
# Best fitness: -0.19088 - size: (9, 4) - species 7 - id 64027
# Average adjusted fitness: 0.823
# Mean genetic distance 2.344, standard deviation 0.325
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   51    72    -17.6    0.852     0
#      6   16   314    -23.8    0.800     3
#      7    5   614    -21.7    0.817     0
# Total extinctions: 0
# Generation time: 4.882 sec (3.534 average)
# Saving checkpoint to neat-checkpoint-64
#
#  ****** Running generation 65 ******
#
# Population's average fitness: -24.16655 stdev: 25.59793
# Best fitness: -0.18396 - size: (9, 4) - species 7 - id 64027
# Average adjusted fitness: 0.765
# Mean genetic distance 2.416, standard deviation 0.318
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   52    91    -24.9    0.762     1
#      6   17   411    -25.3    0.758     4
#      7    6   498    -23.5    0.775     1
# Total extinctions: 0
# Generation time: 3.871 sec (3.606 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: -22.75838 stdev: 27.86789
# Best fitness: -0.17245 - size: (9, 12) - species 6 - id 66307
# Average adjusted fitness: 0.802
# Mean genetic distance 2.374, standard deviation 0.316
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   53   216    -23.8    0.794     2
#      6   18   539    -20.5    0.823     5
#      7    7   245    -24.5    0.788     2
# Total extinctions: 0
# Generation time: 3.083 sec (3.575 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: -21.85187 stdev: 32.47927
# Best fitness: -0.13947 - size: (11, 14) - species 2 - id 65567
# Average adjusted fitness: 0.821
# Mean genetic distance 2.264, standard deviation 0.307
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   54   143    -23.4    0.814     3
#      6   19   281    -20.4    0.837     6
#      7    8   576    -23.6    0.812     3
# Total extinctions: 0
# Generation time: 3.173 sec (3.567 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: -22.59596 stdev: 29.07683
# Best fitness: -0.32505 - size: (11, 14) - species 2 - id 65567
# Average adjusted fitness: 0.816
# Mean genetic distance 2.253, standard deviation 0.308
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   55   208    -20.9    0.828     4
#      6   20   263    -23.5    0.806     7
#      7    9   529    -22.6    0.814     4
# Total extinctions: 0
# Generation time: 2.920 sec (3.582 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: -22.04409 stdev: 28.12001
# Best fitness: -0.18748 - size: (13, 17) - species 7 - id 69417
# Average adjusted fitness: 0.803
# Mean genetic distance 2.249, standard deviation 0.312
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   56   192    -20.8    0.816     5
#      6   21   342    -24.9    0.780     8
#      7   10   466    -21.1    0.813     0
# Total extinctions: 0
# Generation time: 2.932 sec (3.570 average)
# Saving checkpoint to neat-checkpoint-69
#
#  ****** Running generation 70 ******
#
# Population's average fitness: -22.13483 stdev: 30.87901
# Best fitness: -0.31268 - size: (9, 9) - species 7 - id 70099
# Average adjusted fitness: 0.833
# Mean genetic distance 2.214, standard deviation 0.296
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   57   182    -22.9    0.827     6
#      6   22   361    -20.8    0.843     9
#      7   11   457    -22.8    0.827     1
# Total extinctions: 0
# Generation time: 3.613 sec (3.426 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: -24.21037 stdev: 23.51696
# Best fitness: -0.08528 - size: (12, 15) - species 7 - id 71142
# Average adjusted fitness: 0.746
# Mean genetic distance 2.208, standard deviation 0.297
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   58   161    -22.9    0.758     7
#      6   23   422    -24.8    0.738    10
#      7   12   417    -24.2    0.744     2
# Total extinctions: 0
# Generation time: 3.332 sec (3.425 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: -23.65535 stdev: 31.99186
# Best fitness: -0.31029 - size: (12, 14) - species 6 - id 71833
# Average adjusted fitness: 0.824
# Mean genetic distance 2.238, standard deviation 0.317
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   59   126    -20.8    0.841     8
#      6   24   459    -24.9    0.810    11
#      7   13   415    -23.5    0.820     3
# Total extinctions: 0
# Generation time: 4.087 sec (3.519 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: -24.89093 stdev: 29.35725
# Best fitness: -0.18332 - size: (11, 13) - species 2 - id 73417
# Average adjusted fitness: 0.782
# Mean genetic distance 2.288, standard deviation 0.317
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   60   217    -23.8    0.789     9
#      6   25   184    -25.2    0.776    12
#      7   14   599    -24.8    0.780     4
# Total extinctions: 0
# Generation time: 3.704 sec (3.560 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: -21.02490 stdev: 32.29000
# Best fitness: -0.19387 - size: (11, 13) - species 2 - id 73417
# Average adjusted fitness: 0.847
# Mean genetic distance 2.267, standard deviation 0.328
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   61   248    -18.4    0.862    10
#      6   26   317    -20.5    0.846    13
#      7   15   435    -22.2    0.833     5
# Total extinctions: 0
# Generation time: 4.204 sec (3.492 average)
# Saving checkpoint to neat-checkpoint-74
#
#  ****** Running generation 75 ******
#
# Population's average fitness: -21.70442 stdev: 31.76707
# Best fitness: -0.27811 - size: (9, 12) - species 6 - id 66307
# Average adjusted fitness: 0.833
# Mean genetic distance 2.251, standard deviation 0.295
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   62   209    -19.5    0.848    11
#      6   27   359    -23.3    0.819    14
#      7   16   432    -21.8    0.831     6
# Total extinctions: 0
# Generation time: 4.561 sec (3.561 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: -23.81143 stdev: 27.21059
# Best fitness: -0.22000 - size: (9, 12) - species 6 - id 66307
# Average adjusted fitness: 0.786
# Mean genetic distance 2.180, standard deviation 0.312
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   63    50    -23.7    0.786    12
#      6   28   752    -22.3    0.799    15
#      7   17   198    -25.1    0.774     7
# Total extinctions: 0
# Generation time: 3.546 sec (3.607 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: -23.03732 stdev: 25.36040
# Best fitness: -0.21064 - size: (11, 14) - species 6 - id 77153
# Average adjusted fitness: 0.792
# Mean genetic distance 2.142, standard deviation 0.335
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   64    30    -22.1    0.796    13
#      6   29   796    -23.3    0.785    16
#      7   18   174    -22.2    0.795     8
# Total extinctions: 0
# Generation time: 3.510 sec (3.641 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: -21.89039 stdev: 25.18634
# Best fitness: -0.22696 - size: (9, 12) - species 6 - id 66307
# Average adjusted fitness: 0.799
# Mean genetic distance 2.155, standard deviation 0.369
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   65    25    -24.6    0.782    14
#      6   30   686    -21.8    0.807    17
#      7   19   289    -21.9    0.807     9
# Total extinctions: 0
# Generation time: 3.074 sec (3.656 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: -20.96477 stdev: 35.36822
# Best fitness: -0.21829 - size: (12, 13) - species 7 - id 78292
# Average adjusted fitness: 0.835
# Mean genetic distance 2.228, standard deviation 0.385
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   66    30    -26.7    0.806    15
#      6   31   620    -20.8    0.850    18
#      7   20   350    -20.9    0.849     0
# Total extinctions: 0
# Generation time: 3.132 sec (3.676 average)
# Saving checkpoint to neat-checkpoint-79
#
#  ****** Running generation 80 ******
#
# Population's average fitness: -23.05626 stdev: 28.96107
# Best fitness: -0.25798 - size: (8, 8) - species 7 - id 78823
# Average adjusted fitness: 0.832
# Mean genetic distance 2.258, standard deviation 0.368
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   67    54    -14.8    0.880     0
#      6   32   778    -22.5    0.817    19
#      7   21   168    -24.8    0.798     1
# Total extinctions: 0
# Generation time: 3.721 sec (3.687 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: -22.40914 stdev: 29.69148
# Best fitness: -0.31935 - size: (8, 8) - species 7 - id 78823
#
# Species 6 with 778 members is stagnated: removing it
# Average adjusted fitness: 0.831
# Mean genetic distance 2.128, standard deviation 0.367
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   68   181    -18.5    0.848     1
#      7   22   819    -22.6    0.814     2
# Total extinctions: 0
# Generation time: 3.043 sec (3.658 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: -24.69442 stdev: 27.04624
# Best fitness: -0.12591 - size: (9, 7) - species 7 - id 82408
# Average adjusted fitness: 0.763
# Mean genetic distance 2.078, standard deviation 0.328
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   69   320    -26.0    0.755     2
#      7   23   680    -24.4    0.770     3
# Total extinctions: 0
# Generation time: 2.837 sec (3.533 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: -22.81020 stdev: 33.20890
# Best fitness: -0.17745 - size: (10, 8) - species 2 - id 83181
# Average adjusted fitness: 0.823
# Mean genetic distance 2.092, standard deviation 0.291
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   70   299    -22.4    0.825     3
#      7   24   701    -23.0    0.820     4
# ...
#
# Population's average fitness: -22.35231 stdev: 27.29270
# Best fitness: -0.11343 - size: (12, 6) - species 16 - id 173132
# Average adjusted fitness: 0.773
# Mean genetic distance 2.309, standard deviation 0.422
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     14   19   449    -24.2    0.773    18
#     15   16    88    -28.6    0.731     8
#     16   16   130    -20.0    0.812     8
#     17   14   333    -23.8    0.776     1
# Total extinctions: 0
# Generation time: 4.505 sec (3.448 average)
# Saving checkpoint to neat-checkpoint-174
#
#  ****** Running generation 175 ******
#
# Population's average fitness: -23.16200 stdev: 29.84066
# Best fitness: -0.32386 - size: (14, 6) - species 17 - id 173258
# Average adjusted fitness: 0.806
# Mean genetic distance 2.514, standard deviation 0.378
# Population of 1000 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     14   20   458    -22.3    0.817    19
#     15   17    72    -24.6    0.799     9
#     16   17    74    -24.7    0.798     9
#     17   15   396    -23.3    0.809     2
# Total extinctions: 0
# Generation time: 4.259 sec (3.551 average)
#
#  ****** Running generation 176 ******
#
# Population's average fitness: -25.03411 stdev: 25.37064
# Best fitness: -0.21578 - size: (9, 5) - species 17 - id 175227
#
# Species 14 with 458 members is stagnated: removing it
# Average adjusted fitness: 0.748
# Mean genetic distance 2.590, standard deviation 0.365
# Population of 1001 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   18   131    -28.9    0.720    10
#     16   18   462    -24.6    0.761    10
#     17   16   408    -24.5    0.763     3
# Total extinctions: 0
# Generation time: 4.460 sec (3.699 average)
#
#  ****** Running generation 177 ******
#
# Population's average fitness: -22.91270 stdev: 23.69871
# Best fitness: -0.18140 - size: (14, 8) - species 17 - id 174534
# Average adjusted fitness: 0.781
# Mean genetic distance 2.546, standard deviation 0.341
# Population of 1001 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   19   104    -19.2    0.810    11
#     16   19   438    -22.1    0.781    11
#     17   17   459    -25.0    0.752     4
# Total extinctions: 0
# Generation time: 3.703 sec (3.696 average)
#
#  ****** Running generation 178 ******
#
# Population's average fitness: -24.26619 stdev: 28.58713
# Best fitness: -0.19737 - size: (22, 22) - species 17 - id 177508
# Average adjusted fitness: 0.784
# Mean genetic distance 2.494, standard deviation 0.324
# Population of 1001 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   20   103    -24.4    0.783    12
#     16   20   315    -23.9    0.788    12
#     17   18   583    -24.6    0.781     5
# Total extinctions: 0
# Generation time: 3.276 sec (3.729 average)
#
#  ****** Running generation 179 ******
#
# Population's average fitness: -26.11805 stdev: 24.01940
# Best fitness: -0.24208 - size: (14, 8) - species 16 - id 174534
# Average adjusted fitness: 0.730
# Mean genetic distance 2.415, standard deviation 0.347
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   21   103    -23.3    0.754    13
#     16   21   693    -27.7    0.707    13
#     17   19   204    -25.8    0.728     6
# Total extinctions: 0
# Generation time: 3.814 sec (3.742 average)
# Saving checkpoint to neat-checkpoint-179
#
#  ****** Running generation 180 ******
#
# Population's average fitness: -23.01970 stdev: 24.07395
# Best fitness: -0.30135 - size: (13, 8) - species 16 - id 179183
# Average adjusted fitness: 0.782
# Mean genetic distance 2.412, standard deviation 0.391
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   22    78    -22.4    0.790    14
#     16   22   565    -22.6    0.789    14
#     17   20   357    -24.9    0.767     7
# Total extinctions: 0
# Generation time: 4.828 sec (3.880 average)
#
#  ****** Running generation 181 ******
#
# Population's average fitness: -20.79234 stdev: 28.42602
# Best fitness: -0.17968 - size: (16, 10) - species 16 - id 180631
# Average adjusted fitness: 0.812
# Mean genetic distance 2.500, standard deviation 0.429
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   23    61    -29.1    0.759    15
#     16   23   247    -21.6    0.822    15
#     17   21   692    -17.7    0.854     0
# Total extinctions: 0
# Generation time: 4.545 sec (4.008 average)
#
#  ****** Running generation 182 ******
#
# Population's average fitness: -23.23727 stdev: 26.12548
# Best fitness: -0.21804 - size: (17, 15) - species 16 - id 181625
# Average adjusted fitness: 0.760
# Mean genetic distance 2.449, standard deviation 0.405
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   24    70    -27.8    0.733    16
#     16   24   417    -24.7    0.762    16
#     17   22   513    -22.3    0.786     1
# Total extinctions: 0
# Generation time: 2.827 sec (3.962 average)
#
#  ****** Running generation 183 ******
#
# Population's average fitness: -23.66486 stdev: 29.98920
# Best fitness: -0.04514 - size: (17, 15) - species 16 - id 181625
# Average adjusted fitness: 0.783
# Mean genetic distance 2.460, standard deviation 0.419
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   25    58    -23.4    0.785    17
#     16   25   516    -23.4    0.785    17
#     17   23   426    -23.9    0.780     2
# Total extinctions: 0
# Generation time: 4.489 sec (4.071 average)
#
#  ****** Running generation 184 ******
#
# Population's average fitness: -25.21266 stdev: 28.20632
# Best fitness: -0.33320 - size: (14, 6) - species 15 - id 180930
# Average adjusted fitness: 0.760
# Mean genetic distance 2.577, standard deviation 0.404
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   26    69    -32.8    0.711    18
#     16   26   489    -25.6    0.775    18
#     17   24   442    -23.6    0.793     3
# Total extinctions: 0
# Generation time: 4.054 sec (4.026 average)
# Saving checkpoint to neat-checkpoint-184
#
#  ****** Running generation 185 ******
#
# Population's average fitness: -23.71670 stdev: 31.61406
# Best fitness: -0.29060 - size: (10, 6) - species 15 - id 183388
# Average adjusted fitness: 0.799
# Mean genetic distance 2.652, standard deviation 0.380
# Population of 1000 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   27    75    -30.0    0.763    19
#     16   27   533    -24.3    0.808    19
#     17   25   392    -22.1    0.825     4
# Total extinctions: 0
# Generation time: 4.038 sec (4.003 average)
#
#  ****** Running generation 186 ******
#
# Population's average fitness: -22.28749 stdev: 32.71077
# Best fitness: -0.07755 - size: (10, 6) - species 15 - id 184866
#
# Species 15 with 75 members is stagnated: removing it
# Average adjusted fitness: 0.819
# Mean genetic distance 2.380, standard deviation 0.290
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   28   173    -22.3    0.819    20
#     17   26   827    -22.2    0.820     5
# Total extinctions: 0
# Generation time: 3.302 sec (3.888 average)
#
#  ****** Running generation 187 ******
#
# Population's average fitness: -22.80445 stdev: 27.68130
# Best fitness: -0.13441 - size: (16, 10) - species 17 - id 186806
# Average adjusted fitness: 0.807
# Mean genetic distance 2.330, standard deviation 0.287
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   29   287    -19.4    0.826    21
#     17   27   713    -23.5    0.788     6
# Total extinctions: 0
# Generation time: 3.785 sec (3.896 average)
#
#  ****** Running generation 188 ******
#
# Population's average fitness: -22.31700 stdev: 33.86079
# Best fitness: -0.31026 - size: (14, 8) - species 17 - id 186699
# Average adjusted fitness: 0.831
# Mean genetic distance 2.387, standard deviation 0.286
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   30   209    -23.4    0.826    22
#     17   28   791    -21.9    0.837     7
# Total extinctions: 0
# Generation time: 4.501 sec (4.018 average)
#
#  ****** Running generation 189 ******
#
# Population's average fitness: -22.24313 stdev: 29.10641
# Best fitness: -0.18417 - size: (14, 8) - species 17 - id 186699
# Average adjusted fitness: 0.805
# Mean genetic distance 2.343, standard deviation 0.291
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   31   320    -26.1    0.785    23
#     17   29   680    -21.2    0.825     8
# Total extinctions: 0
# Generation time: 5.045 sec (4.142 average)
# Saving checkpoint to neat-checkpoint-189
#
#  ****** Running generation 190 ******
#
# Population's average fitness: -23.13731 stdev: 25.91835
# Best fitness: -0.22514 - size: (22, 21) - species 16 - id 188973
# Average adjusted fitness: 0.793
# Mean genetic distance 2.300, standard deviation 0.262
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   32   381    -22.6    0.796    24
#     17   30   619    -23.4    0.789     9
# Total extinctions: 0
# Generation time: 4.311 sec (4.090 average)
#
#  ****** Running generation 191 ******
#
# Population's average fitness: -24.59594 stdev: 27.01952
# Best fitness: -0.31028 - size: (22, 20) - species 17 - id 189442
# Average adjusted fitness: 0.789
# Mean genetic distance 2.328, standard deviation 0.259
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   33   539    -22.5    0.803    25
#     17   31   461    -25.9    0.774    10
# Total extinctions: 0
# Generation time: 3.697 sec (4.005 average)
#
#  ****** Running generation 192 ******
#
# Population's average fitness: -24.74498 stdev: 29.03578
# Best fitness: -0.31617 - size: (22, 20) - species 16 - id 189442
# Average adjusted fitness: 0.790
# Mean genetic distance 2.394, standard deviation 0.265
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   34   399    -24.1    0.796    26
#     17   32   601    -25.5    0.784    11
# Total extinctions: 0
# Generation time: 4.892 sec (4.211 average)
#
#  ****** Running generation 193 ******
#
# Population's average fitness: -23.21047 stdev: 30.38752
# Best fitness: -0.16407 - size: (16, 11) - species 17 - id 190129
# Average adjusted fitness: 0.803
# Mean genetic distance 2.443, standard deviation 0.285
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   35   374    -23.7    0.800    27
#     17   33   626    -22.9    0.807    12
# Total extinctions: 0
# Generation time: 3.766 sec (4.139 average)
#
#  ****** Running generation 194 ******
#
# Population's average fitness: -24.86995 stdev: 28.05104
# Best fitness: -0.29827 - size: (22, 21) - species 16 - id 193409
# Average adjusted fitness: 0.767
# Mean genetic distance 2.420, standard deviation 0.258
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   36   261    -26.3    0.756    28
#     17   34   739    -24.0    0.777    13
# Total extinctions: 0
# Generation time: 4.270 sec (4.161 average)
# Saving checkpoint to neat-checkpoint-194
#
#  ****** Running generation 195 ******
#
# Population's average fitness: -24.02874 stdev: 29.48491
# Best fitness: -0.17530 - size: (12, 9) - species 17 - id 193924
# Average adjusted fitness: 0.785
# Mean genetic distance 2.291, standard deviation 0.299
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   37    57    -24.6    0.781    29
#     17   35   943    -23.8    0.788    14
# Total extinctions: 0
# Generation time: 4.472 sec (4.204 average)
#
#  ****** Running generation 196 ******
#
# Population's average fitness: -23.72242 stdev: 26.66141
# Best fitness: -0.14941 - size: (22, 17) - species 17 - id 195325
# Average adjusted fitness: 0.754
# Mean genetic distance 2.189, standard deviation 0.324
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   38    35    -28.6    0.729    30
#     17   36   965    -23.4    0.778    15
# Total extinctions: 0
# Generation time: 3.780 sec (4.252 average)
#
#  ****** Running generation 197 ******
#
# Population's average fitness: -24.35249 stdev: 29.68134
# Best fitness: -0.30946 - size: (13, 7) - species 17 - id 196009
# Average adjusted fitness: 0.778
# Mean genetic distance 2.198, standard deviation 0.318
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   39   124    -28.4    0.760    31
#     17   37   876    -24.2    0.796    16
# Total extinctions: 0
# Generation time: 5.701 sec (4.443 average)
#
#  ****** Running generation 198 ******
#
# Population's average fitness: -21.83012 stdev: 27.23697
# Best fitness: -0.31147 - size: (22, 17) - species 17 - id 195325
# Average adjusted fitness: 0.819
# Mean genetic distance 2.191, standard deviation 0.310
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   40   132    -21.0    0.823    32
#     17   38   868    -21.9    0.816    17
# Total extinctions: 0
# Generation time: 3.650 sec (4.358 average)
#
#  ****** Running generation 199 ******
#
# Population's average fitness: -23.48385 stdev: 28.39412
# Best fitness: -0.35152 - size: (19, 17) - species 17 - id 198366
# Average adjusted fitness: 0.801
# Mean genetic distance 2.098, standard deviation 0.299
# Population of 1000 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16   41   152    -23.5    0.801    33
#     17   39   848    -23.5    0.801    18
# Total extinctions: 0
# Generation time: 4.663 sec (4.320 average)
# Saving checkpoint to neat-checkpoint-199
#
# Best genome:
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.5124507423078064, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-9.940480203211676, response=1.0, activation=sigmoid, aggregation=sum)
# 	6 DefaultNodeGene(key=6, bias=1.7663177043280232, response=1.0, activation=sigmoid, aggregation=sum)
# 	8 DefaultNodeGene(key=8, bias=5.427686099988414, response=1.0, activation=sigmoid, aggregation=sum)
# 	11 DefaultNodeGene(key=11, bias=1.7176452319235431, response=1.0, activation=sigmoid, aggregation=sum)
# 	9 DefaultNodeGene(key=9, bias=-1.9567693970847946, response=1.0, activation=sigmoid, aggregation=sum)
# 	4 DefaultNodeGene(key=4, bias=-2.3898140256529445, response=1.0, activation=sigmoid, aggregation=sum)
# 	14 DefaultNodeGene(key=14, bias=-0.8548932890870372, response=1.0, activation=sigmoid, aggregation=sum)
# 	17 DefaultNodeGene(key=17, bias=2.8515837312084225, response=1.0, activation=sigmoid, aggregation=sum)
# 	7 DefaultNodeGene(key=7, bias=-3.924817010372708, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-3, 8), weight=0.006536431225073497, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=1.0906320286400275, enabled=True)
# 	DefaultConnectionGene(key=(0, 6), weight=-0.018117613814270822, enabled=True)
# 	DefaultConnectionGene(key=(0, 9), weight=2.1459582711610894, enabled=True)
# 	DefaultConnectionGene(key=(7, 6), weight=-1.7727483382285307, enabled=True)
# 	DefaultConnectionGene(key=(8, 14), weight=1.333930070845943, enabled=True)
#
# Output:

# %%
o = 2000
l = 500
predicted = list(predict(winner_net, o, l))
plt.figure(figsize=(20, 10))
plt.plot(predicted, label="Predicted by winner")
plt.plot(data[o:(o+l),1], label="Throttle input")
plt.plot(data[o:(o+l),2], label="Steering input")
plt.plot(data[o:(o+l),3], label="Expected")
plt.legend()
plt.show()

# %%
import math
max_rpm_normalized = 1.0

def torque(rpm, stall_torque):
    return stall_torque - (stall_torque / max_rpm_normalized) * rpm

def predict_torque(rpm, throttle, steering, x):
    drive_torque = torque(rpm, x[0]) * throttle
    load_torque = (rpm ** x[2]) * ((x[3] + x[4] * abs(steering)) ** x[5])

    return (drive_torque - load_torque) / x[1]

dt = 1./25.
steering_adjustment_step = 6.25 * dt
        
def predict_custom(offset, n, x):
    rpm = float(data[offset, 0])
    for row in data[offset:(offset + n)]:   
        motor_rpm_acc = predict_torque(rpm, row[1], row[2], x)        
        rpm = max(0, rpm + motor_rpm_acc * dt)
        yield rpm
        
o = 0
l = 2000
x = [800.0, 800.0, 2, 10.0, 5.0, 3.0]
predicted = np.array(list(predict_custom(o, l, x)))

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, sharey=True, figsize=(20, 10))

ax0.plot(data[o:(o+l),1], label="Throttle input")
ax0.plot(data[o:(o+l),2], label="Steering input")
ax0.plot(data[o:(o+l),3], 'g', label="Expected")
ax0.plot(predicted, 'r', label="Predicted by model")
ax1.plot(data[o:(o+l),3], 'g', label="Expected")
ax1.plot(predicted, 'r', label="Predicted by model")
ax1.legend()
ax0.legend()
plt.show()

# %%
from scipy.optimize import minimize

def err(x):
    err = 0
    offset = 0
    for csv in csvs:
        predicted = predict_custom(offset, len(csv), x)
        offset += len(csv)
        for (pred, ref) in zip(predicted, data):
            err += (pred - ref[3]) ** 2
        return err

x0 = [800.0, 800.0, 2, 2.0, 2.0, 3.0]
bnds = ((0, 10000), (0, 10000), (0, 10000), (0, 10000), (0, 1000), (0, 1000)) # positive numbers
res = minimize(err, x0, method='SLSQP', bounds=bnds).x

print(res)
# Out:
# [7.33016701e+02 8.58626896e+02 7.40739969e-01 7.68248846e+01
#  2.05190302e+02 1.16584276e+00]

# %%
l = 2700
o = 8000

print(res)

# for csv in csvs:
#     o += l
#     l = len(csv)
predicted = np.array(list(predict_custom(o, l, res)))

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, sharey=True, figsize=(20, 10))

ax0.plot(data[o:(o+l),1], label="Throttle input")
ax0.plot(data[o:(o+l),2], label="Steering input")
ax0.plot(data[o:(o+l),3], 'g--', label="Measured RPM (normalized)")
#ax0.plot(predicted, 'r', label="Predicted by model")
ax1.plot(data[o:(o+l),3], 'g--', label="Measured RPM (normalized)")
ax1.plot(predicted, 'r', label="Predicted by model")
ax1.legend()
ax0.legend()

plt.xlabel("time [s]")
plt.xticks([0, 500, 1000, 1500, 2000, 2500], [0, 20, 40, 60, 80, 100])

plt.show()
# plt.savefig("fit_{}.pdf".format(o));
# Out:
# [7.33016701e+02 8.58626896e+02 7.40739969e-01 7.68248846e+01
#  2.05190302e+02 1.16584276e+00]
