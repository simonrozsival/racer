# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
max_rpm = 15350

input_files = ("telemetry_highspeed.csv", "telemetry_lowspeed.csv", "telemetry_05.csv", "telemetry_06.csv", "telemetry_07.csv")
csvs = []
period = 12
for file in input_files:
    csv = pd.read_csv(file)
    csv["motor_rpm"] = np.convolve(csv["motor_rpm"], np.ones((period,)) / period, mode='same')
    csvs += [csv]
    
for csv in csvs:    
    plt.figure(figsize=(20, 10))
    plt.grid()
    #plt.plot(csv["throttle_input"], label="throttle")
    #plt.plot(csv["steering_angle_input"], label="steering angle")
    plt.plot(csv["motor_rpm"] / max_rpm, label="RPM")
    plt.legend()
    plt.show()

# %%
# I want the intput to be in the form of:
# (current RPM, throttle input, steering input, RPM change rate)

import numpy as np

data = np.array(np.zeros(4))

for csv in csvs:
    previous_rpm = 0
    for index, row in csv.iterrows():
        next_rpm = row["motor_rpm"] / max_rpm       
        previous_rpm = next_rpm
        
        record = [previous_rpm, row["throttle_input"], row["steering_angle_input"], next_rpm]
        
        data = np.vstack((data, record))

plt.figure(figsize=(20, 10))
plt.grid()
plt.plot(data[:, 0], label="current rpm")
plt.plot(data[:, 1], label="throttle")
#plt.plot(data[:, 2], label="steering angle")
plt.legend()
plt.show()

# %%
#np.random.shuffle(data)

training_portion = 0.8
split_point = int(len(data)*training_portion)
test = data[:split_point,:]
train = data[split_point:,:]

x_test = test[:, :-1]
y_test = test[:, -1]

x_train = train[:, :-1]
y_train = train[:, -1]

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(len(x_test[0]), activation='relu'),
  tf.keras.layers.Dense(4, activation='relu'),
  tf.keras.layers.Dense(2, activation='relu'),
  tf.keras.layers.Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),
              loss='mean_squared_error',
              metrics=['mean_absolute_error', 'mean_squared_error'])

model.fit(x_train, y_train, epochs=100, use_multiprocessing=True)

model.evaluate(x_test, y_test)
# Out:
# Train on 2947 samples
# Epoch 1/100
# 2947/2947 [==============================] - 1s 373us/sample - loss: 0.1055 - mean_absolute_error: 0.2671 - mean_squared_error: 0.1055
# Epoch 2/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 0.0648 - mean_absolute_error: 0.1980 - mean_squared_error: 0.0648
# Epoch 3/100
# 2947/2947 [==============================] - 0s 58us/sample - loss: 0.0442 - mean_absolute_error: 0.1546 - mean_squared_error: 0.0442
# Epoch 4/100
# 2947/2947 [==============================] - 0s 57us/sample - loss: 0.0376 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0376
# Epoch 5/100
# 2947/2947 [==============================] - 0s 57us/sample - loss: 0.0372 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0372
# Epoch 6/100
# 2947/2947 [==============================] - 0s 47us/sample - loss: 0.0372 - mean_absolute_error: 0.1434 - mean_squared_error: 0.0372
# Epoch 7/100
# 2947/2947 [==============================] - 0s 56us/sample - loss: 0.0372 - mean_absolute_error: 0.1429 - mean_squared_error: 0.0372
# Epoch 8/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 0.0371 - mean_absolute_error: 0.1438 - mean_squared_error: 0.0371
# Epoch 9/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 0.0365 - mean_absolute_error: 0.1416 - mean_squared_error: 0.0365
# Epoch 10/100
# 2947/2947 [==============================] - 0s 53us/sample - loss: 0.0231 - mean_absolute_error: 0.1024 - mean_squared_error: 0.0231
# Epoch 11/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 0.0110 - mean_absolute_error: 0.0591 - mean_squared_error: 0.0110
# Epoch 12/100
# 2947/2947 [==============================] - 0s 61us/sample - loss: 0.0051 - mean_absolute_error: 0.0339 - mean_squared_error: 0.0051
# Epoch 13/100
# 2947/2947 [==============================] - 0s 61us/sample - loss: 0.0023 - mean_absolute_error: 0.0226 - mean_squared_error: 0.0023
# Epoch 14/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 9.8901e-04 - mean_absolute_error: 0.0156 - mean_squared_error: 9.8901e-04
# Epoch 15/100
# 2947/2947 [==============================] - 0s 59us/sample - loss: 4.5405e-04 - mean_absolute_error: 0.0108 - mean_squared_error: 4.5405e-04
# Epoch 16/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 2.5853e-04 - mean_absolute_error: 0.0084 - mean_squared_error: 2.5853e-04
# Epoch 17/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 1.8449e-04 - mean_absolute_error: 0.0074 - mean_squared_error: 1.8449e-04
# Epoch 18/100
# 2947/2947 [==============================] - 0s 52us/sample - loss: 1.4415e-04 - mean_absolute_error: 0.0066 - mean_squared_error: 1.4415e-04
# Epoch 19/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 1.2343e-04 - mean_absolute_error: 0.0066 - mean_squared_error: 1.2343e-04
# Epoch 20/100
# 2947/2947 [==============================] - 0s 50us/sample - loss: 1.0589e-04 - mean_absolute_error: 0.0061 - mean_squared_error: 1.0589e-04
# Epoch 21/100
# 2947/2947 [==============================] - 0s 54us/sample - loss: 9.8999e-05 - mean_absolute_error: 0.0062 - mean_squared_error: 9.8999e-05
# Epoch 22/100
# 2947/2947 [==============================] - 0s 58us/sample - loss: 9.0415e-05 - mean_absolute_error: 0.0058 - mean_squared_error: 9.0415e-05
# Epoch 23/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 8.5621e-05 - mean_absolute_error: 0.0059 - mean_squared_error: 8.5621e-05
# Epoch 24/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 7.6277e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 7.6277e-05
# Epoch 25/100
# 2947/2947 [==============================] - 0s 64us/sample - loss: 7.0055e-05 - mean_absolute_error: 0.0056 - mean_squared_error: 7.0055e-05
# Epoch 26/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 6.5217e-05 - mean_absolute_error: 0.0056 - mean_squared_error: 6.5217e-05
# Epoch 27/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 6.0035e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 6.0035e-05
# Epoch 28/100
# 2947/2947 [==============================] - 0s 71us/sample - loss: 5.7628e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 5.7628e-05
# Epoch 29/100
# 2947/2947 [==============================] - 0s 65us/sample - loss: 5.5186e-05 - mean_absolute_error: 0.0052 - mean_squared_error: 5.5186e-05
# Epoch 30/100
# 2947/2947 [==============================] - 0s 61us/sample - loss: 5.3528e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 5.3528e-05
# Epoch 31/100
# 2947/2947 [==============================] - 0s 58us/sample - loss: 4.9243e-05 - mean_absolute_error: 0.0049 - mean_squared_error: 4.9243e-05
# Epoch 32/100
# 2947/2947 [==============================] - 0s 57us/sample - loss: 5.2391e-05 - mean_absolute_error: 0.0056 - mean_squared_error: 5.2391e-05
# Epoch 33/100
# 2947/2947 [==============================] - 0s 53us/sample - loss: 4.8234e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 4.8234e-05
# Epoch 34/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 5.0856e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 5.0856e-05
# Epoch 35/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 4.9363e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 4.9363e-05
# Epoch 36/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 4.8746e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 4.8746e-05
# Epoch 37/100
# 2947/2947 [==============================] - 0s 48us/sample - loss: 4.7728e-05 - mean_absolute_error: 0.0057 - mean_squared_error: 4.7728e-05
# Epoch 38/100
# 2947/2947 [==============================] - 0s 48us/sample - loss: 4.6072e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.6072e-05
# Epoch 39/100
# 2947/2947 [==============================] - 0s 54us/sample - loss: 4.7957e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.7957e-05
# Epoch 40/100
# 2947/2947 [==============================] - 0s 61us/sample - loss: 4.5664e-05 - mean_absolute_error: 0.0056 - mean_squared_error: 4.5664e-05
# Epoch 41/100
# 2947/2947 [==============================] - 0s 54us/sample - loss: 4.6178e-05 - mean_absolute_error: 0.0049 - mean_squared_error: 4.6178e-05
# Epoch 42/100
# 2947/2947 [==============================] - 0s 47us/sample - loss: 4.1859e-05 - mean_absolute_error: 0.0048 - mean_squared_error: 4.1859e-05
# Epoch 43/100
# 2947/2947 [==============================] - 0s 59us/sample - loss: 4.6199e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.6199e-05
# Epoch 44/100
# 2947/2947 [==============================] - 0s 68us/sample - loss: 4.3736e-05 - mean_absolute_error: 0.0052 - mean_squared_error: 4.3736e-05
# Epoch 45/100
# 2947/2947 [==============================] - 0s 70us/sample - loss: 4.3127e-05 - mean_absolute_error: 0.0050 - mean_squared_error: 4.3127e-05
# Epoch 46/100
# 2947/2947 [==============================] - 0s 85us/sample - loss: 4.5172e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.5172e-05
# Epoch 47/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 4.3697e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.3697e-05
# Epoch 48/100
# 2947/2947 [==============================] - 0s 109us/sample - loss: 4.3034e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.3034e-05
# Epoch 49/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 4.2679e-05 - mean_absolute_error: 0.0048 - mean_squared_error: 4.2679e-05
# Epoch 50/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 4.2954e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.2954e-05
# Epoch 51/100
# 2947/2947 [==============================] - 0s 51us/sample - loss: 4.3682e-05 - mean_absolute_error: 0.0048 - mean_squared_error: 4.3682e-05
# Epoch 52/100
# 2947/2947 [==============================] - 0s 53us/sample - loss: 3.9326e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 3.9326e-05
# Epoch 53/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 4.2750e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 4.2750e-05
# Epoch 54/100
# 2947/2947 [==============================] - 0s 58us/sample - loss: 4.1014e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 4.1014e-05
# Epoch 55/100
# 2947/2947 [==============================] - 0s 54us/sample - loss: 4.1414e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 4.1414e-05
# Epoch 56/100
# 2947/2947 [==============================] - 0s 47us/sample - loss: 4.1648e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 4.1648e-05
# Epoch 57/100
# 2947/2947 [==============================] - 0s 48us/sample - loss: 4.0870e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 4.0870e-05
# Epoch 58/100
# 2947/2947 [==============================] - 0s 65us/sample - loss: 3.9566e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 3.9566e-05
# Epoch 59/100
# 2947/2947 [==============================] - 0s 47us/sample - loss: 4.1062e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 4.1062e-05
# Epoch 60/100
# 2947/2947 [==============================] - 0s 49us/sample - loss: 3.9507e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 3.9507e-05
# Epoch 61/100
# 2947/2947 [==============================] - 0s 47us/sample - loss: 4.0521e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 4.0521e-05
# Epoch 62/100
# 2947/2947 [==============================] - 0s 47us/sample - loss: 3.3643e-05 - mean_absolute_error: 0.0043 - mean_squared_error: 3.3643e-05
# Epoch 63/100
# 2947/2947 [==============================] - 0s 65us/sample - loss: 4.2112e-05 - mean_absolute_error: 0.0050 - mean_squared_error: 4.2112e-05
# Epoch 64/100
# 2947/2947 [==============================] - 0s 72us/sample - loss: 3.9083e-05 - mean_absolute_error: 0.0052 - mean_squared_error: 3.9083e-05
# Epoch 65/100
# 2947/2947 [==============================] - 0s 54us/sample - loss: 4.0012e-05 - mean_absolute_error: 0.0056 - mean_squared_error: 4.0012e-05
# Epoch 66/100
# 2947/2947 [==============================] - 0s 50us/sample - loss: 3.7148e-05 - mean_absolute_error: 0.0048 - mean_squared_error: 3.7148e-05
# Epoch 67/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 3.7850e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 3.7850e-05
# Epoch 68/100
# 2947/2947 [==============================] - 0s 81us/sample - loss: 3.9609e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 3.9609e-05
# Epoch 69/100
# 2947/2947 [==============================] - 0s 75us/sample - loss: 3.8552e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 3.8552e-05
# Epoch 70/100
# 2947/2947 [==============================] - 0s 95us/sample - loss: 3.7246e-05 - mean_absolute_error: 0.0049 - mean_squared_error: 3.7246e-05
# Epoch 71/100
# 2947/2947 [==============================] - 0s 99us/sample - loss: 3.9816e-05 - mean_absolute_error: 0.0057 - mean_squared_error: 3.9816e-05
# Epoch 72/100
# 2947/2947 [==============================] - 0s 82us/sample - loss: 3.6875e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 3.6875e-05
# Epoch 73/100
# 2947/2947 [==============================] - 0s 75us/sample - loss: 3.7105e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 3.7105e-05
# Epoch 74/100
# 2947/2947 [==============================] - 0s 76us/sample - loss: 3.7082e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 3.7082e-05
# Epoch 75/100
# 2947/2947 [==============================] - 0s 61us/sample - loss: 3.6656e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 3.6656e-05
# Epoch 76/100
# 2947/2947 [==============================] - 0s 66us/sample - loss: 3.8152e-05 - mean_absolute_error: 0.0056 - mean_squared_error: 3.8152e-05
# Epoch 77/100
# 2947/2947 [==============================] - 0s 84us/sample - loss: 3.5522e-05 - mean_absolute_error: 0.0048 - mean_squared_error: 3.5522e-05
# Epoch 78/100
# 2947/2947 [==============================] - 0s 68us/sample - loss: 3.6344e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 3.6344e-05
# Epoch 79/100
# 2947/2947 [==============================] - 0s 64us/sample - loss: 3.7475e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 3.7475e-05
# Epoch 80/100
# 2947/2947 [==============================] - 0s 78us/sample - loss: 3.5251e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 3.5251e-05
# Epoch 81/100
# 2947/2947 [==============================] - 0s 85us/sample - loss: 3.6096e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 3.6096e-05
# Epoch 82/100
# 2947/2947 [==============================] - 0s 78us/sample - loss: 3.5856e-05 - mean_absolute_error: 0.0049 - mean_squared_error: 3.5856e-05
# Epoch 83/100
# 2947/2947 [==============================] - 0s 78us/sample - loss: 3.6239e-05 - mean_absolute_error: 0.0050 - mean_squared_error: 3.6239e-05
# Epoch 84/100
# 2947/2947 [==============================] - 0s 69us/sample - loss: 3.4878e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 3.4878e-05
# Epoch 85/100
# 2947/2947 [==============================] - 0s 63us/sample - loss: 3.3728e-05 - mean_absolute_error: 0.0049 - mean_squared_error: 3.3728e-05
# Epoch 86/100
# 2947/2947 [==============================] - 0s 68us/sample - loss: 3.4361e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 3.4361e-05
# Epoch 87/100
# 2947/2947 [==============================] - 0s 65us/sample - loss: 3.6374e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 3.6374e-05
# Epoch 88/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 3.4713e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 3.4713e-05
# Epoch 89/100
# 2947/2947 [==============================] - 0s 58us/sample - loss: 3.5123e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 3.5123e-05
# Epoch 90/100
# 2947/2947 [==============================] - 0s 65us/sample - loss: 3.4526e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 3.4526e-05
# Epoch 91/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 3.5040e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 3.5040e-05
# Epoch 92/100
# 2947/2947 [==============================] - 0s 57us/sample - loss: 3.4272e-05 - mean_absolute_error: 0.0053 - mean_squared_error: 3.4272e-05
# Epoch 93/100
# 2947/2947 [==============================] - 0s 56us/sample - loss: 3.5870e-05 - mean_absolute_error: 0.0056 - mean_squared_error: 3.5870e-05
# Epoch 94/100
# 2947/2947 [==============================] - 0s 60us/sample - loss: 3.3230e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 3.3230e-05
# Epoch 95/100
# 2947/2947 [==============================] - 0s 62us/sample - loss: 3.4049e-05 - mean_absolute_error: 0.0050 - mean_squared_error: 3.4049e-05
# Epoch 96/100
# 2947/2947 [==============================] - 0s 53us/sample - loss: 3.4988e-05 - mean_absolute_error: 0.0055 - mean_squared_error: 3.4988e-05
# Epoch 97/100
# 2947/2947 [==============================] - 0s 78us/sample - loss: 3.4044e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 3.4044e-05
# Epoch 98/100
# 2947/2947 [==============================] - 0s 96us/sample - loss: 3.4465e-05 - mean_absolute_error: 0.0052 - mean_squared_error: 3.4465e-05
# Epoch 99/100
# 2947/2947 [==============================] - 0s 65us/sample - loss: 3.4032e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 3.4032e-05
# Epoch 100/100
# 2947/2947 [==============================] - 0s 61us/sample - loss: 3.5206e-05 - mean_absolute_error: 0.0054 - mean_squared_error: 3.5206e-05
# 11787/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.00028769190574855685, 0.005733112, 0.00028769183]

# %%
predicted_rpm = []
rpm = 0
for row in data[:4500]:
    rpm = float(model.predict([(rpm, row[1], row[2])])[0][0])
    predicted_rpm += [rpm]

# %%
plt.figure(figsize=(20, 10))
plt.grid()
plt.plot(data[:1000, 1], label="throttle")
#plt.plot(data[:1000, 1], label="steering angle")
#plt.plot(data[:,-1], 'b', label="measured RPM")
plt.plot(predicted_rpm, 'r', label="predicted RPM")
plt.legend()
plt.show()
